# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
df = pd.read_csv('weather delhi.csv')

# %%
df.head()
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100990 entries, 0 to 100989
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datetime_utc  100990 non-null  object
#  1    _conds       100918 non-null  object
#  2    _dewptm      100369 non-null  float64
#  3    _fog         100990 non-null  int64
#  4    _hail        100990 non-null  int64
#  5    _heatindexm  29155 non-null   float64
#  6    _hum         100233 non-null  float64
#  7    _precipm     0 non-null       float64
#  8    _pressurem   100758 non-null  float64
#  9    _rain        100990 non-null  int64
#  10   _snow        100990 non-null  int64
#  11   _tempm       100317 non-null  float64
#  12   _thunder     100990 non-null  int64
#  13   _tornado     100990 non-null  int64
#  14   _vism        96562 non-null   float64
#  15   _wdird       86235 non-null   float64
#  16   _wdire       86235 non-null   object
# ...

# %%
df.describe(include='all')
# Out:
#           datetime_utc  _conds        _dewptm           _fog          _hail  \
# count           100990  100918  100369.000000  100990.000000  100990.000000
# unique          100990      39            NaN            NaN            NaN
# top     19961101-11:00    Haze            NaN            NaN            NaN
# freq                 1   47602            NaN            NaN            NaN
# mean               NaN     NaN      15.741205       0.069690       0.000129
# std                NaN     NaN       7.058587       0.254625       0.011345
# min                NaN     NaN     -24.000000       0.000000       0.000000
# 25%                NaN     NaN      10.000000       0.000000       0.000000
# 50%                NaN     NaN      15.000000       0.000000       0.000000
# 75%                NaN     NaN      22.000000       0.000000       0.000000
# max                NaN     NaN      75.000000       1.000000       1.000000
#
# ...

# %%
df.sample(10)
# Out:
#          datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 17405  19991219-16:30   Smoke       7.0      0       0           NaN   63.0
# 33007  20020307-12:30    Haze       1.0      0       0           NaN   18.0
# 7278   19971105-14:40   Smoke      15.0      0       0           NaN   64.0
# 75158  20090622-15:00    Haze      15.0      0       0           NaN   18.0
# 17471  19991222-18:30   Smoke       7.0      0       0           NaN   72.0
# 49999  20031021-04:30   Smoke      13.0      0       0           NaN   44.0
# 29077  20010919-08:30    Haze      11.0      0       0           NaN   18.0
# 68738  20070324-18:00    Mist      15.0      0       0           NaN   69.0
# 66090  20060422-18:00    Haze      14.0      0       0           NaN   37.0
# 18794  20000221-01:30   Smoke       9.0      0       0           NaN   82.0
#
#         _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# ...

# %%
df.isnull().sum()
# Out:
# datetime_utc         0
#  _conds             72
#  _dewptm           621
#  _fog                0
#  _hail               0
#  _heatindexm     71835
#  _hum              757
#  _precipm       100990
#  _pressurem        232
#  _rain               0
#  _snow               0
#  _tempm            673
#  _thunder            0
#  _tornado            0
#  _vism            4428
#  _wdird          14755
#  _wdire          14755
#  _wgustm         99918
#  _windchillm    100411
#  _wspdm           2358
# dtype: int64

# %%
100*df.isnull().sum()/len(df)
# Out:
# datetime_utc      0.000000
#  _conds           0.071294
#  _dewptm          0.614912
#  _fog             0.000000
#  _hail            0.000000
#  _heatindexm     71.130805
#  _hum             0.749579
#  _precipm       100.000000
#  _pressurem       0.229726
#  _rain            0.000000
#  _snow            0.000000
#  _tempm           0.666403
#  _thunder         0.000000
#  _tornado         0.000000
#  _vism            4.384593
#  _wdird          14.610357
#  _wdire          14.610357
#  _wgustm         98.938509
#  _windchillm     99.426676
#  _wspdm           2.334885
# dtype: float64

# %%
df.columns
# Out:
# Index(['datetime_utc', ' _conds', ' _dewptm', ' _fog', ' _hail',
#        ' _heatindexm', ' _hum', ' _precipm', ' _pressurem', ' _rain', ' _snow',
#        ' _tempm', ' _thunder', ' _tornado', ' _vism', ' _wdird', ' _wdire',
#        ' _wgustm', ' _windchillm', ' _wspdm'],
#       dtype='object')

# %%
drop_cols = [' _precipm','datetime_utc',' _heatindexm',' _wgustm',' _windchillm']
df.drop(drop_cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#    _conds   _dewptm   _fog   _hail   _hum   _pressurem   _rain   _snow  \
# 0   Smoke       9.0      0       0   27.0       1010.0       0       0
# 1   Smoke      10.0      0       0   32.0      -9999.0       0       0
# 2   Smoke      11.0      0       0   44.0      -9999.0       0       0
# 3   Smoke      10.0      0       0   41.0       1010.0       0       0
# 4   Smoke      11.0      0       0   47.0       1011.0       0       0
#
#     _tempm   _thunder   _tornado   _vism   _wdird  _wdire   _wspdm
# 0     30.0          0          0     5.0    280.0    West      7.4
# 1     28.0          0          0     NaN      0.0   North      NaN
# 2     24.0          0          0     NaN      0.0   North      NaN
# 3     24.0          0          0     2.0      0.0   North      NaN
# 4     23.0          0          0     1.2      0.0   North      0.0

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80891 entries, 0 to 100989
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0    _conds      80891 non-null  object
#  1    _dewptm     80891 non-null  float64
#  2    _fog        80891 non-null  int64
#  3    _hail       80891 non-null  int64
#  4    _hum        80891 non-null  float64
#  5    _pressurem  80891 non-null  float64
#  6    _rain       80891 non-null  int64
#  7    _snow       80891 non-null  int64
#  8    _tempm      80891 non-null  float64
#  9    _thunder    80891 non-null  int64
#  10   _tornado    80891 non-null  int64
#  11   _vism       80891 non-null  float64
#  12   _wdird      80891 non-null  float64
#  13   _wdire      80891 non-null  object
#  14   _wspdm      80891 non-null  float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 9.9+ MB

# %%
# Renaming Columns

df.rename(columns={col:col.lstrip(' _') for col in df.columns},inplace=True)

# %%
df.head()
# Out:
#     conds  dewptm  fog  hail   hum  pressurem  rain  snow  tempm  thunder  \
# 0   Smoke     9.0    0     0  27.0     1010.0     0     0   30.0        0
# 4   Smoke    11.0    0     0  47.0     1011.0     0     0   23.0        0
# 6   Smoke    13.0    0     0  60.0     1010.0     0     0   21.0        0
# 14  Smoke    10.0    0     0  52.0     1011.0     0     0   20.0        0
# 15  Smoke    10.0    0     0  46.0     1012.0     0     0   22.0        0
#
#     tornado  vism  wdird  wdire  wspdm
# 0         0   5.0  280.0   West    7.4
# 4         0   1.2    0.0  North    0.0
# 6         0   0.8    0.0  North    0.0
# 14        0   2.0  200.0    SSW    9.3
# 15        0   3.5  240.0    WSW    9.3

# %%
df.columns
# Out:
# Index(['conds', 'dewptm', 'fog', 'hail', 'hum', 'pressurem', 'rain', 'snow',
#        'tempm', 'thunder', 'tornado', 'vism', 'wdird', 'wdire', 'wspdm'],
#       dtype='object')

# %%
num_cols=['dewptm', 'pressurem','hum', 'vism', 'wdird', 'wspdm']
cat_cols=[ 'fog', 'hail','rain', 'snow', 'thunder', 'tornado']
target_col = 'tempm'

# %%
for col in df.columns:
    print(f'{col}:{df[col].nunique()}')
    print(df[col].unique())
    print('-'*20)
# Out:
# conds:37
# ['Smoke' 'Clear' 'Haze' 'Unknown' 'Scattered Clouds' 'Shallow Fog'
#  'Mostly Cloudy' 'Fog' 'Partly Cloudy' 'Patches of Fog'
#  'Thunderstorms and Rain' 'Overcast' 'Rain' 'Light Rain' 'Drizzle' 'Mist'
#  'Light Drizzle' 'Thunderstorm' 'Light Thunderstorms and Rain'
#  'Light Thunderstorm' 'Squalls' 'Heavy Rain' 'Light Haze'
#  'Widespread Dust' 'Funnel Cloud' 'Heavy Thunderstorms and Rain'
#  'Heavy Thunderstorms with Hail' 'Light Rain Showers'
#  'Thunderstorms with Hail' 'Partial Fog' 'Heavy Fog' 'Light Fog'
#  'Blowing Sand' 'Sandstorm' 'Light Hail Showers' 'Light Sandstorm'
#  'Rain Showers']
# --------------------
# dewptm:50
# [  9.  11.  13.  10.   8.   7.  12.  14.   5.   6.   4.   2.   1.   3.
#   -1.   0.  -4.  -2.  -3.  -5.  -7.  -6.  15.  16.  27.  17.  18.  19.
#   20.  21.  24.  22.  23.  28.  26.  25.  29.  30.  31.  32.  33. -24.
#  -12. -23.  -8.  35. -14.  -9. -21. -11.]
# --------------------
# fog:2
# [0 1]
# --------------------
# hail:2
# [0 1]
# ...

# %%
def cat_analyze(col):
    print(col)
    print(df[col].value_counts().sort_index())
    sns.countplot(data = df, y=col)
    plt.show()
for col in cat_cols:
    cat_analyze(col)

def num_analyze(col):
    print(col)
    fig = plt.figure(figsize=(15,3))
    sns.distplot(df[col],bins = 300)
    plt.show()
for col in num_cols:
    num_analyze(col)

# Bivariate Analysis
def cat_bivariate(col):
    print(col)        
    plt.figure(figsize=(15,4))
    plt.subplot(1,3,1)    
    sns.barplot(data=df,y=target_col,x=col)
    plt.subplot(1,3,2)
    sns.boxplot(data=df,y=target_col, x=col)
    plt.subplot(1,3,3)
    sns.violinplot(data=df,y=target_col, x=col)
    plt.show()
for col in cat_cols:
    cat_bivariate(col)


def num_bivariate(col):
    print(col)
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)    
    sns.regplot(data=df,x=target_col,y=col)
    plt.subplot(1,2,2)
    sns.kdeplot(data=df,x=target_col, y=col)
    plt.show()
for col in num_cols:
    num_bivariate(col)
# Out:
# fog
# 0    76785
# 1     4106
# Name: fog, dtype: int64
# hail
# 0    80880
# 1       11
# Name: hail, dtype: int64
# rain
# 0    78705
# 1     2186
# Name: rain, dtype: int64
# snow
# 0    80890
# 1        1
# Name: snow, dtype: int64
# thunder
# 0    80067
# 1      824
# Name: thunder, dtype: int64
# tornado
# 0    80889
# 1        2
# Name: tornado, dtype: int64
# dewptm
# pressurem
# hum
# vism
# wdird
# wspdm
# fog
# hail
# rain
# snow
# thunder
# tornado
# dewptm
# pressurem
# hum
# vism
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\HP\Desktop\ML IT training\weather.ipynb Cell 19 in <cell line: 40>()
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/Desktop/ML%20IT%20training/weather.ipynb#X24sZmlsZQ%3D%3D?line=38'>39</a>     plt.show()
# ...

# %%
# Finding Quantiles
def find_outliers(x):
    q3 = df[x].quantile(0.75)
    q1 = df[x].quantile(0.25)
    iqr = q3-q1
    max_lim = q3 + (iqr * 1.5)

    min_lim = q1 - (iqr * 1.5)
    return min_lim,max_lim

# %%
_,max_limwdird = find_outliers('wdird')
print(_)
print(max_limwdird)
# Out:
# -255.0
# 585.0

# %%
# removing outliers
# we sorted these and saw a unusual spike thats why we removed that
df =df[df['pressurem']<df['pressurem'].max()]
df = df[df['vism']<df['vism'].max()]
df = df[df['wdird']<max_limwdird]

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df[num_cols + cat_cols + target_col].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
feats = ['dewptm','vism','wdird','wspdm','hum','fog']

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df[feats + target_col].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(df[feats],df[target_col],test_size= 0.25,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

model_lin = LinearRegression().fit(xtrain,ytrain)
model_dt = DecisionTreeRegressor().fit(xtrain,ytrain)
model_rf = RandomForestRegressor().fit(xtrain,ytrain)

print('Linear Model(Train)',round(model_lin.score(xtrain,ytrain)*100,1),'%')
print('Linear Model(Test)',round(model_lin.score(xtest,ytest)*100,1),'%')

print('Decision tree(Train)',round(model_dt.score(xtrain,ytrain)*100,1),'%')
print('Decision tree(Test)',round(model_dt.score(xtest,ytest)*100,1),'%')

print('RF Model(Train)',round(model_rf.score(xtrain,ytrain)*100,1),'%')
print('RF Model(Test)',round(model_rf.score(xtest,ytest)*100,1),'%')
# Out:
# Linear Model(Train) 91.3 %
# Linear Model(Test) -732.3 %
# Decision tree(Train) 100.0 %
# Decision tree(Test) 97.9 %
# RF Model(Train) 99.8 %
# RF Model(Test) 98.9 %

# %%
pd.DataFrame(model_rf.feature_importances_,columns=['imp'],index=xtrain.columns).sort_values(by='imp',ascending=False)
# Out:
#              imp
# vism    0.343394
# hum     0.341334
# dewptm  0.315272

# %%
# to improve model by taking few features:
feats=['dewptm', 'vism', 'hum']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(df[feats],df[target_col],test_size= 0.25,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

model_lin = LinearRegression().fit(xtrain,ytrain)
model_dt = DecisionTreeRegressor().fit(xtrain,ytrain)
model_rf = RandomForestRegressor().fit(xtrain,ytrain)

print('Linear Model(Train)',round(model_lin.score(xtrain,ytrain)*100,1),'%')
print('Linear Model(Test)',round(model_lin.score(xtest,ytest)*100,1),'%')

print('Decision tree(Train)',round(model_dt.score(xtrain,ytrain)*100,1),'%')
print('Decision tree(Test)',round(model_dt.score(xtest,ytest)*100,1),'%')

print('RF Model(Train)',round(model_rf.score(xtrain,ytrain)*100,1),'%')
print('RF Model(Test)',round(model_rf.score(xtest,ytest)*100,1),'%')
# Out:
# Linear Model(Train) 91.0 %
# Linear Model(Test) 91.2 %
# Decision tree(Train) 99.1 %
# Decision tree(Test) 98.6 %
# RF Model(Train) 99.1 %
# RF Model(Test) 98.7 %

# %%
# we can do same for humidity by using 'hum':
feats_h=['dewptm', 'vism', 'tempm']
target_col_h='hum'
xtrain_h,xtest_h,ytrain_h,ytest_h = train_test_split(df[feats_h],df[target_col_h],test_size= 0.25,random_state=101)
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

model_lin_h = LinearRegression().fit(xtrain_h,ytrain_h)
model_dt_h = DecisionTreeRegressor().fit(xtrain_h,ytrain_h)
model_rf_h = RandomForestRegressor().fit(xtrain_h,ytrain_h)

print('Linear Model(Train)',round(model_lin_h.score(xtrain_h,ytrain_h)*100,1),'%')
print('Linear Model(Test)',round(model_lin_h.score(xtest_h,ytest_h)*100,1),'%')

print('Decision tree(Train)',round(model_dt_h.score(xtrain_h,ytrain_h)*100,1),'%')
print('Decision tree(Test)',round(model_dt_h.score(xtest_h,ytest_h)*100,1),'%')

print('RF Model(Train)',round(model_rf_h.score(xtrain_h,ytrain_h)*100,1),'%')
print('RF Model(Test)',round(model_rf_h.score(xtest_h,ytest_h)*100,1),'%')
# Out:
# Linear Model(Train) 89.3 %
# Linear Model(Test) 89.2 %
# Decision tree(Train) 99.0 %
# Decision tree(Test) 98.7 %
# RF Model(Train) 99.0 %
# RF Model(Test) 98.7 %

# %%
pd.to_pickle(model_rf,'TempraturePrediction.pickle')
pd.to_pickle(model_rf_h,'HumidityPrediction.pickle')
